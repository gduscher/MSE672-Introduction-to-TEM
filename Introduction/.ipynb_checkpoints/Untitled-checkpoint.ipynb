# %%
# %pylab notebook
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "../../sidpy/")

import sidpy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
raw_data_3d = np.random.random([5,5,6])
x_vec = np.arange(5)
y_vec = np.arange(5)
 
fig, axes = sidpy.plot_utils.plot_map_stack(raw_data_3d, reverse_dims=True, pad_mult=(0.15, 0.15),
                                            title='Spatial maps of current at different bias', stdevs=2,
                                            y_label='dfef', x_label='dfef',
                                            color_bar_mode='each', num_ticks=3, x_vec=x_vec, y_vec=y_vec,
                                            evenly_spaced=True, fig_mult=(3, 3), title_yoffset=0.95, colorbar_label='nex')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
import numpy as np
from matplotlib import cbook
import matplotlib.colors
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# from https://matplotlib.org/3.3.3/gallery/axes_grid1/demo_axes_grid2.html
# *** Demo 2: shared colorbar ***
plt.rcParams["mpl_toolkits.legacy_colorbar"] = False

fig = plt.figure()
grid2 = ImageGrid(fig, 111,
                  nrows_ncols=(2, 2),
                  axes_pad=0.35,
                  label_mode="L",
                  share_all=True,
                  cbar_location="right",
                  cbar_mode="single",
                  cbar_size="4%",
                  cbar_pad=0.05,
                  )

grid2[0].set_xlabel("X")
grid2[0].set_ylabel("Y")

ZS = np.random.random([4,10,10])
vmax, vmin = np.max(ZS), np.min(ZS)
norm = matplotlib.colors.Normalize(vmax=vmax, vmin=vmin)


for ax, z in zip(grid2, ZS):
    im = ax.imshow(z, norm=norm, origin="lower")#, extent=extent)

# With cbar_mode="single", cax attribute of all axes are identical.
    ax.cax.colorbar(im)
#ax.cax.toggle_label(True)


#grid2[0].set_xticks([-2, 0])
#grid2[0].set_yticks([-2, 0, 2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import h5py
dd = h5py.File('test.hdf5', mode='a')

# %%
dd['hhh/jjj/kkk'] = 1

# %%
print(dd['hhh'])
# Out:
# <HDF5 group "/hhh" (1 members)>

# %% [markdown]
# https://codereview.stackexchange.com/questions/120802/recursively-save-python-dictionaries-to-hdf5-files-using-h5py

# %%
dictio = {'gg': {'ff':1, 'jj':2}}

def recursively_save_dict_contents_to_group(h5file, path, dictionary):
    """
    Take an already open HDF5 file and insert the contents of a dictionary
    at the current path location. Can call itself recursively to fill
    out HDF5 files with the contents of a dictionary.
    """
    if not isinstance(dictionary, dict):
        raise TypeError("must provide a dictionary")
    if not isinstance(path, str):
        raise TypeError("path must be a string")
    if not isinstance(h5file, h5py._hl.files.File):
            raise ValueError("must be an open h5py file")   
    for key in dic:
        if isinstance(key, [str, int, list]):
            if isinstance(key, ):
                
                
            
            
            
recursively_save_dict_contents_to_group(dd, '/hhh', dictio)

# %%
    
        assert type(path) is types.StringType, "path must be a string"
    assert type(h5file) is h5py._hl.files.File, "must be an open h5py file"
    for key in dic:
        assert type(key) == types.StringType, 'dict keys must be strings to save to hdf5'
        if type(dic[key]) in (np.int64, np.float64, types.StringType):
            h5file[path + key] = dic[key]
            assert h5file[path + key].value == dic[key], 'The data representation in the HDF5 file does not match the original dict.'
        if type(dic[key]) is np.ndarray:
            h5file[path + key] = dic[key]
            assert np.array_equal(h5file[path + key].value, dic[key]), 'The data representation in the HDF5 file does not match the original dict.'
        elif type(dic[key]) is types.DictionaryType:
            cls.__recursively_save_dict_contents_to_group__(h5file, path + key + '/', dic[key])

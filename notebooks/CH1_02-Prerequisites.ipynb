# %% [markdown]
# <font size = "5"> **Chapter 1: [Introduction](CH1_00-Introduction.ipynb)** </font>
#
#
# <hr style="height:1px;border-top:4px solid #FF8200" />
#
# # Prerequisites
#
#
# part of
#
# <font size = "5"> **[MSE672:  Introduction to Transmission Electron Microscopy](_MSE672_Intro_TEM.ipynb)**</font>
#
# by Gerd Duscher, Fall 2021
#
# Microscopy Facilities<br>
# Joint Institute of Advanced Materials<br>
# Materials Science & Engineering<br>
# The University of Tennessee, Knoxville
#
# Background and methods to analysis and quantification of data acquired with transmission electron microscopes.

# %% [markdown]
# ## Language
# The notebooks are all in python 3.
#
# At this point the common version is python 3.7

# %% [markdown]
# ## Packages
# The idea behind any python program is to make use of the hghly efficient libraries that already exist.
#
# I use [anaconda3](https://www.anaconda.com/distribution/) (not miniconda) which is available for all major operating systems.
#
# We us a few modules that come with every python installation, like:
#
# * math
# * sys
# * os
#
# We use mostly the common packages for scientific computing in python (all included in anaconda3)
# The most important ones are:
# * [Numpy](https://www.numpy.org/) - the numerical library
# * [Scipy](https://www.scipy.org/scipylib/index.html) the scientific library
# * [Matplotlib](https://www.matplotlib.org/) the interactive plotting library
#
#
# These notebooks are expected to be installed on your computer to run the notebooks of this book.
#
#
# For specialist applications we do not reinvent the wheel and use those on an as needed basis.
# Example is the library to register a stack of images:
# * [SimpleITK](https://www.simpleitk.org)
# integration of AI in image analysis and for high performing computer algrothyms
# * [pyNSID](https://pycroscopy.github.io/pyNSID/about.html)
# the atomistic simulation program is used for crystallographic data
# * [ase](https://wiki.fysik.dtu.dk/ase/)
# together with a symmetry package
# * [spglib](https://atztogo.github.io/spglib/)
#
#
# For dialogs we use the capabilities provided by:
# * [PyQt5](https://www.riverbankcomputing.com/software/pyqt/intro)
#
# All routines that are introduced in the notebooks are also available (for analysis) in the provided package
# * [pyTEMlib](https://github.com/pycroscopy/pyTEMlib)
#
#
# If you install **[pyTEMlib](#TEM-Library)** with the code cell below all packages you need for this book will be installed.

# %% [markdown]
# ## Data Format
# All data in this course are stored in the data format of
# * [pyNSID](https://pycroscopy.github.io/pyNSID/about.html)
#
# which is based on
# * [HDF5](https://www.h5py.org/)
#
#
#
# ## Notebook preamble
# As a minimum Any notebook in this course has to have the following libraries loaded :

# %%
# import matplotlib and numpy with this **magic** comand
#                       use "inline" instead of "notebook" for non-interactive plots
# %pylab --no-import-all notebook
# on jupyterlab you will need to install ipympl and change notebook to widgets.

# here we import the backend to show dialog boxes such as the **open file dialog**
# %gui qt5
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Numpy
#
# The calculations depend on **Numpy** and an installation of that package that is compiled to include BLAS and LAPACK libraries will be much faster than the standalone version.
# For example the numpy installed on ubuntu with *> sudo apt-get install python3-numpy* or at windows you can install the numpy package from Gohlke's webpage which compiled against the MKL library of Intel. If you used anaconda3, everything is already optimized.
#
# The comand below lets you see what you have

# %%
## What is numpy compiled against
np.__config__.show()
print('numpy version: ',np.version.version)
import scipy as sp
print('scipy version: ',sp.__version__)
# Out:
# blas_mkl_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/gduscher/Anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\include', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\lib', 'C:/Users/gduscher/Anaconda3\\Library\\include']
# blas_opt_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/gduscher/Anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\include', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\lib', 'C:/Users/gduscher/Anaconda3\\Library\\include']
# lapack_mkl_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/gduscher/Anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\include', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\lib', 'C:/Users/gduscher/Anaconda3\\Library\\include']
# lapack_opt_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/gduscher/Anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\include', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2019.0.117\\windows\\mkl\\lib', 'C:/Users/gduscher/Anaconda3\\Library\\include']
# numpy version:  1.18.5
# scipy version:  1.6.0

# %% [markdown]
# ## TEM Library
#
#
# You will have to run the code cell below **at least once** to install the library with the programs needed for the analysis of data.
#
# The  code cell below will install pyTEMlib  directly from pypi

# %%
import sys
from pkg_resources import get_distribution, DistributionNotFound

def test_package(package_name):
    """Test if package exists and returns version or -1"""
    try:
        version = (get_distribution(package_name).version)
    except (DistributionNotFound, ImportError) as err:
        version = '-1'
    return version

# Colab setup ------------------
if 'google.colab' in sys.modules:
    # !pip install git+https://github.com/pycroscopy/pyTEMlib/ -q

# pyTEMlib setup ------------------
else:
    if test_package('pyTEMlib') < '0.2021.1.9':
        print('installing pyTEMlib')
        # !{sys.executable} -m pip install  --upgrade pyTEMlib -q
# ------------------------------
print('done')
# Out:
# Requirement already up-to-date: pyTEMlib in c:\users\gduscher\anaconda3\lib\site-packages (0.2020.4.2)
# Requirement already satisfied, skipping upgrade: simpleITK in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (1.2.4)
# Requirement already satisfied, skipping upgrade: scikit-image in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (0.17.2)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (1.18.1)
# Requirement already satisfied, skipping upgrade: pyUSID in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (0.0.8.1)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (0.23.1)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (1.4.1)
# Requirement already satisfied, skipping upgrade: ase in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (3.19.1)
# Requirement already satisfied, skipping upgrade: pillow in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (7.1.2)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in c:\users\gduscher\anaconda3\lib\site-packages (from scikit-image->pyTEMlib) (3.2.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in c:\users\gduscher\anaconda3\lib\site-packages (from scikit-image->pyTEMlib) (2.4)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in c:\users\gduscher\anaconda3\lib\site-packages (from scikit-image->pyTEMlib) (2.8.0)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in c:\users\gduscher\anaconda3\lib\site-packages (from scikit-image->pyTEMlib) (2020.6.3)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in c:\users\gduscher\anaconda3\lib\site-packages (from scikit-image->pyTEMlib) (1.1.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (1.15.0)
# Requirement already satisfied, skipping upgrade: dask>=0.10 in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (2.18.0)
# Requirement already satisfied, skipping upgrade: h5py>=2.6.0 in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (2.10.0)
# Requirement already satisfied, skipping upgrade: ipywidgets>=5.2.2 in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (7.5.1)
# Requirement already satisfied, skipping upgrade: toolz in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: ipython>=6.0; python_version >= "3.3" in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (7.15.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11.0 in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (0.15.1)
# Requirement already satisfied, skipping upgrade: cytoolz in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (0.10.1)
# Requirement already satisfied, skipping upgrade: psutil in c:\users\gduscher\anaconda3\lib\site-packages (from pyUSID->pyTEMlib) (5.7.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\gduscher\anaconda3\lib\site-packages (from scikit-learn->pyTEMlib) (2.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->pyTEMlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->pyTEMlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->pyTEMlib) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->pyTEMlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in c:\users\gduscher\anaconda3\lib\site-packages (from networkx>=2.0->scikit-image->pyTEMlib) (4.4.2)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\gduscher\anaconda3\lib\site-packages (from dask>=0.10->pyUSID->pyTEMlib) (5.3.1)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyUSID->pyTEMlib) (3.5.1)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyUSID->pyTEMlib) (5.0.6)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyUSID->pyTEMlib) (4.3.3)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyUSID->pyTEMlib) (5.3.0)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (0.7.5)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (0.1.0)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (2.6.1)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (0.15.2)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (3.0.5)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (0.4.3)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\gduscher\appdata\roaming\python\python37\site-packages (from ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (41.0.1)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\gduscher\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (6.0.3)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\gduscher\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\gduscher\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (4.6.3)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\gduscher\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (3.2.0)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in c:\users\gduscher\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (6.0.4)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\gduscher\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (6.1.3)
# Requirement already satisfied, skipping upgrade: parso>=0.5.2 in c:\users\gduscher\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (0.5.2)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\gduscher\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0; python_version >= "3.3"->pyUSID->pyTEMlib) (0.2.3)
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (2.11.2)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.8.3)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.8.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (19.0.1)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (5.6.1)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (1.5.0)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\gduscher\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (227)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\gduscher\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.16.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in c:\users\gduscher\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (1.6.1)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in c:\users\gduscher\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (19.3.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\gduscher\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (1.1.1)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.8.4)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (3.1.5)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (1.4.2)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.3)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.4.4)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.6.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\gduscher\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (3.1.0)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\gduscher\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (0.5.1)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\gduscher\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyUSID->pyTEMlib) (20.4)

# %%
import pyTEMlib
print(f'pyTEM version: {pyTEMlib.__version__}')
# Out:
# pyTEM version: 0.2021.01.09

# %%
import sys
# get rid of annoying update pip installer
# !{sys.executable} -m pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\users\gdusc\anaconda3\lib\site-packages (19.1.1)

# %% [markdown]
# ## Test
# Let's test if the installation ws succesfull and plot a unit cell. You can rotate the plot around, zoom and select. Try it!

# %%
import pyTEMlib.KinsCat as ks # Import kinematic sCattering Library fromt he pyTEMlib

# make a structure dictionary
tags = ks.structure_by_name('Graphite')

# define bond length for plot
tags['max_bond_length'] = 0.246

# plot it in 3D
ks.plot_unitcell(tags)
# Out:
# Using KinsCat library version  0.5  by G.Duscher
# spglib not installed; Symmetry functions of spglib disabled
# ['C', 'C', 'C', 'C']
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Get used to changing parameters and type **silicon** instead of **Graphite** in the code cell above.

# %% [markdown]
# ## Summary
#
# We now have tested all tools to load data and save our analysis.
#
# We are ready to go

# %% [markdown]
# ## Navigation
# - **Next: [Matplotlib and Numpy for Micrographs](CH1_03-Data_Representation.ipynb)**
# - **UP: [Chapter 1](CH1-00-Introduction.ipynb)**
# - **List of Content: [Front](_MSE672_Intro_TEM.ipynb)**

# %% [markdown]
# ## Appendix
#
# I am using some extensions to jupyter notebooks which can be installed with the following cells
#
# I like mostly the table of content extension that shows where in the notebook I am and let's me jump to different parts easily.

# %%
# Install a pip package in the current Jupyter kernel
import sys

# !{sys.executable} -m jupyter nbextension list

# %%
# !{sys.executable} -m pip install jupyter_contrib_nbextensions

# %%
# !{sys.executable} -m  jupyter nbextension enable toc2

# %%
# %%javascript
# $('<div id="toc"></div>').css({position: 'fixed', top: '120px', left: 0}).appendTo(document.body);
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js');
